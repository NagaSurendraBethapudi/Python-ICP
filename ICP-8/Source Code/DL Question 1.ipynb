# %% [markdown]
# # Deep Learning - Question 1
#
# ### Use the use case in the class https://umkc.box.com/s/3cvfiwc81lhgygc67deyeqs8m858lld0In  :
# 1. Add more Dense layers to the existing code and check howthe accuracy changes.

# %%
#Importing Libraries
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from sklearn.model_selection import train_test_split

# %%
#Importing the dataset
diabetes = pd.read_csv('diabetes.csv',header = None).values

# %%
#splitting the data into training and testing categories
X_train, X_test, Y_train, Y_test = train_test_split(diabetes[:,0:8], diabetes[:,8],test_size=0.25, random_state=87)

# %%
#Building the sequential model
np.random.seed(155)
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer

#Compilation 
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100,initial_epoch=0)

#Printing the summary and accuarcy of the model
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 18/18 [==============================] - 0s 2ms/step - loss: 32.6237 - acc: 0.3385
# Epoch 2/100
# 18/18 [==============================] - 0s 2ms/step - loss: 18.9617 - acc: 0.3264
# Epoch 3/100
# 18/18 [==============================] - 0s 2ms/step - loss: 8.9081 - acc: 0.3889
# Epoch 4/100
# 18/18 [==============================] - 0s 2ms/step - loss: 5.2283 - acc: 0.5538
# Epoch 5/100
# 18/18 [==============================] - 0s 2ms/step - loss: 3.6317 - acc: 0.5712
# Epoch 6/100
# 18/18 [==============================] - 0s 2ms/step - loss: 3.0671 - acc: 0.5642
# Epoch 7/100
# 18/18 [==============================] - 0s 2ms/step - loss: 2.8352 - acc: 0.5521
# Epoch 8/100
# 18/18 [==============================] - 0s 2ms/step - loss: 2.6094 - acc: 0.5694
# Epoch 9/100
# 18/18 [==============================] - 0s 2ms/step - loss: 2.3725 - acc: 0.5712
# Epoch 10/100
# 18/18 [==============================] - 0s 2ms/step - loss: 2.1177 - acc: 0.5816
# Epoch 11/100
# ...

# %% [markdown]
# #### Observations :
# 1. Loss     = 73%
# 2. Accuracy = 66%

# %% [markdown]
# ### Adding more dense layers

# %%
#Building the sequential model
np.random.seed(155)
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer
my_first_nn.add(Dense(40, activation='relu')) #adding more hidden layers
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100,initial_epoch=0)

print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 18/18 [==============================] - 0s 2ms/step - loss: 4.5061 - acc: 0.5451
# Epoch 2/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.5055 - acc: 0.6024
# Epoch 3/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.1373 - acc: 0.5955
# Epoch 4/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9746 - acc: 0.5938
# Epoch 5/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8742 - acc: 0.6319
# Epoch 6/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8333 - acc: 0.6198
# Epoch 7/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7595 - acc: 0.6458
# Epoch 8/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7877 - acc: 0.6458
# Epoch 9/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7523 - acc: 0.6319
# Epoch 10/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7523 - acc: 0.6285
# Epoch 11/100
# ...

# %% [markdown]
# #### Observations :
# 1. Loss     = 66%
# 2. Accuracy = 69%

# %% [markdown]
# ### Adding more dense layers

# %%
np.random.seed(155)
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer
my_first_nn.add(Dense(40, activation='relu')) #adding more hidden layers
my_first_nn.add(Dense(60, activation='relu')) #adding more hidden layers
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100,initial_epoch=0)

print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 18/18 [==============================] - 0s 2ms/step - loss: 2.6469 - acc: 0.6024
# Epoch 2/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0909 - acc: 0.5972
# Epoch 3/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8291 - acc: 0.6510
# Epoch 4/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7216 - acc: 0.6562
# Epoch 5/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6441 - acc: 0.6736
# Epoch 6/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6412 - acc: 0.6597
# Epoch 7/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6339 - acc: 0.6753
# Epoch 8/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6236 - acc: 0.6910
# Epoch 9/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6268 - acc: 0.6806
# Epoch 10/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6592 - acc: 0.6806
# Epoch 11/100
# ...

# %% [markdown]
# #### Observations :
# 1. Loss     = 61%
# 2. Accuracy = 72%

# %% [markdown]
# ### Adding more dense layers

# %%
np.random.seed(155)
my_first_nn = Sequential() # creating the model
my_first_nn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer
my_first_nn.add(Dense(40, activation='relu')) #adding more hidden layers
my_first_nn.add(Dense(60, activation='relu')) #adding more hidden layers
my_first_nn.add(Dense(100, activation='relu')) #adding more hidden layers
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100,initial_epoch=0)

print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.2550 - acc: 0.5556
# Epoch 2/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6901 - acc: 0.6649
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6229 - acc: 0.6840
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6147 - acc: 0.6736
# Epoch 5/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5936 - acc: 0.6858
# Epoch 6/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6063 - acc: 0.6997
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6051 - acc: 0.6892
# Epoch 8/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6006 - acc: 0.6944
# Epoch 9/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5867 - acc: 0.7031
# Epoch 10/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5619 - acc: 0.7170
# Epoch 11/100
# ...

# %% [markdown]
# #### Observations :
# 1. Loss     = 74%
# 2. Accuracy = 73%

# %% [markdown]
# ## Conclussion :
# 1. Accuracy with one hidden layer   : 66 %
# 2. Accuracy with two hidden layer   : 69 %
# 3. Accuracy with three hidden layer : 72 %
# 4. Accuracy with four hidden layer  : 73 %
#
# <h3> Accuracy is increasing with more dense hidden layers </h3>
